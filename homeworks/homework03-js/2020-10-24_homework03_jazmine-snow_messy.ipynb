# %% [markdown]
# # Homework03 (10 points): Parsing single-cell genomics data
#
# Here we parse the output of a single-cell genomics experiment. Actually just the first couple cells from an experiment. The data is formatted in the style of 10X Genomics output.
#
# There are some potentially useful code snippets at the end of the notebook.
#
# Please post questions to the `lectures-homework` slack channel. Phil is also available via email (pbradley@fredhutch.org).

# %% [markdown]
# ## Looking at the input files
# In the folder where this homework notebook lives, there's a directory `data/` which contains another directory `filtered_feature_bc_matrix/`  with the results of a single-cell genomics experiment.

# %%
# We can list the contents of that directory to see that it contains three files.
# here the %ls is a jupyter notebook thing, not a python thing. % means we are calling
# a built-in jupyter notebook function
# %ls data\filtered_feature_bc_matrix
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 921D-C052
#
#  Directory of C:\Users\jazas\OneDrive\Documents\Grad School\University of Washington-Seattle\Classes\MCB 536\tfcb_2020\homeworks\homework03-js\data\filtered_feature_bc_matrix
#
# 10/22/2020  12:46 PM    <DIR>          .
# 10/22/2020  12:46 PM    <DIR>          ..
# 10/22/2020  12:46 PM               200 barcodes.tsv
# 10/22/2020  12:46 PM         1,516,462 features.tsv
# 10/22/2020  12:46 PM            91,080 matrix.mtx
#                3 File(s)      1,607,742 bytes
#                2 Dir(s)  406,632,419,328 bytes free

# %% [markdown]
# Here's what the files look like, using the unix `head` command to print out the first 5 lines of each.
#
# ```
# rhino01$ head -5 data/filtered_feature_bc_matrix/barcodes.tsv
# AAAGCAACAAGCGTAG-1
# AAAGTAGCATACGCTA-1
# AAAGTAGGTCTCTCGT-1
# AAAGTAGTCCACGTGG-1
# AAATGCCTCACGACTA-1
#
# rhino01$ head -5 data/filtered_feature_bc_matrix/features.tsv
# ENSG00000243485	MIR1302-2HG	Gene Expression
# ENSG00000237613	FAM138A	Gene Expression
# ENSG00000186092	OR4F5	Gene Expression
# ENSG00000238009	AL627309.1	Gene Expression
# ENSG00000239945	AL627309.3	Gene Expression
#
# rhino01$ head -5 data/filtered_feature_bc_matrix/matrix.mtx
# %%MatrixMarket matrix coordinate integer general
# %
# 36620 10 8350
# 42 1 1
# 49 1 1
# ```

# %% [markdown]
# The `barcodes.tsv` file contains DNA barcodes associated to the different cells that were profiled.
#
# The `features.tsv` file describes the features that were analyzed (mRNA transcripts and in this case also surface proteins using DNA-barcoded antibodies).
#
# The `matrix.mtx` file contains the results of the experiment. Each line after the first three header lines contains three integers, FEATURE CELL COUNT, which indicate the COUNT of transcripts mapping to feature number FEATURE in cell number CELL. FEATURE and CELL are numbered 1...N_FEATURES and 1...N_CELLS, respectively.

# %%
## to get started, execute the code in this cell to define some filenames and a useful function

barcodes_file = 'data/filtered_feature_bc_matrix/barcodes.tsv'
features_file = 'data/filtered_feature_bc_matrix/features.tsv'
matrix_file = 'data/filtered_feature_bc_matrix/matrix.mtx'

def read_lines_from_file( filename ):
    '''Returns a list containing all the lines in the given file
    Note: the lines will end with the newline character ('\n'),
    with the possible exception of the last line
    
    Note: we could also do this in a single line:  return open(filename,'r').readlines()
       The downside to that is that the file object may stay open for a little while after
       we read from it. So it's safer to explicitly close the file by calling data.close()
       or by using something we haven't talked about yet called a 'with' statement
    '''
    # open a file object for reading ('r')
    data = open(filename, 'r')
    # read all the lines into a list of strings
    lines = data.readlines()
    # close the file
    data.close()
    # return the lines
    return lines

# %% [markdown]
# ## Q1 (1 pt). How many cells are represented in this experiment?
# Figure this out by reading the lines from `barcodes_file` into a list using the function `read_lines_from_file`, and printing the length of that list.

# %%
open(barcodes_file, 'r')
read_lines_from_file(barcodes_file)
# 10 different cells are represented in this experiment
# Out:
# ['AAAGCAACAAGCGTAG-1\n',
#  'AAAGTAGCATACGCTA-1\n',
#  'AAAGTAGGTCTCTCGT-1\n',
#  'AAAGTAGTCCACGTGG-1\n',
#  'AAATGCCTCACGACTA-1\n',
#  'AACACGTTCAGAGACG-1\n',
#  'AACCATGTCGCAAACT-1\n',
#  'AACCGCGAGCGTCTAT-1\n',
#  'AACCGCGCAAAGGCGT-1\n',
#  'AACCGCGGTCAGCTAT-1\n']

# %% [markdown]
# ## Q2 (1 pt). How many features (mRNA transcripts or surface proteins) are represented in this experiment?
# Figure this out by reading the lines from `features_file` into a list, and printing the length of that list.

# %%
open(features_file, 'r')
read_lines_from_file(features_file)
# Out:
# ['ENSG00000243485\tMIR1302-2HG\tGene Expression\n',
#  'ENSG00000237613\tFAM138A\tGene Expression\n',
#  'ENSG00000186092\tOR4F5\tGene Expression\n',
#  'ENSG00000238009\tAL627309.1\tGene Expression\n',
#  'ENSG00000239945\tAL627309.3\tGene Expression\n',
#  'ENSG00000239906\tAL627309.2\tGene Expression\n',
#  'ENSG00000241860\tAL627309.5\tGene Expression\n',
#  'ENSG00000241599\tAL627309.4\tGene Expression\n',
#  'ENSG00000286448\tAP006222.2\tGene Expression\n',
#  'ENSG00000236601\tAL732372.1\tGene Expression\n',
#  'ENSG00000284733\tOR4F29\tGene Expression\n',
#  'ENSG00000235146\tAC114498.1\tGene Expression\n',
#  'ENSG00000284662\tOR4F16\tGene Expression\n',
#  'ENSG00000229905\tAL669831.2\tGene Expression\n',
#  'ENSG00000237491\tLINC01409\tGene Expression\n',
#  'ENSG00000177757\tFAM87B\tGene Expression\n',
#  'ENSG00000228794\tLINC01128\tGene Expression\n',
#  'ENSG00000225880\tLINC00115\tGene Expression\n',
#  'ENSG00000230368\tFAM41C\tGene Expression\n',
#  'ENSG00000272438\tAL645608.6\tGene Expression\n',
#  'ENSG00000230699\tAL645608.2\tGene Expression\n',
#  'ENSG00000241180\tAL645608.4\tGene Expression\n',
#  'ENSG00000223764\tLINC02593\tGene Expression\n',
#  'ENSG00000187634\tSAMD11\tGene Expression\n',
#  'ENSG00000188976\tNOC2L\tGene Expression\n',
#  'ENSG00000187961\tKLHL17\tGene Expression\n',
#  'ENSG00000187583\tPLEKHN1\tGene Expression\n',
#  'ENSG00000187642\tPERM1\tGene Expression\n',
#  'ENSG00000272512\tAL645608.7\tGene Expression\n',
#  'ENSG00000188290\tHES4\tGene Expression\n',
#  'ENSG00000187608\tISG15\tGene Expression\n',
#  'ENSG00000224969\tAL645608.1\tGene Expression\n',
#  'ENSG00000188157\tAGRN\tGene Expression\n',
#  'ENSG00000242590\tAL645608.5\tGene Expression\n',
#  'ENSG00000273443\tAL645608.8\tGene Expression\n',
#  'ENSG00000237330\tRNF223\tGene Expression\n',
#  'ENSG00000131591\tC1orf159\tGene Expression\n',
#  'ENSG00000285812\tAL390719.3\tGene Expression\n',
#  'ENSG00000223823\tLINC01342\tGene Expression\n',
#  'ENSG00000272141\tAL390719.2\tGene Expression\n',
#  'ENSG00000205231\tTTLL10-AS1\tGene Expression\n',
#  'ENSG00000162571\tTTLL10\tGene Expression\n',
#  'ENSG00000186891\tTNFRSF18\tGene Expression\n',
#  'ENSG00000186827\tTNFRSF4\tGene Expression\n',
#  'ENSG00000078808\tSDF4\tGene Expression\n',
#  'ENSG00000176022\tB3GALT6\tGene Expression\n',
#  'ENSG00000184163\tC1QTNF12\tGene Expression\n',
#  'ENSG00000260179\tAL162741.1\tGene Expression\n',
#  'ENSG00000160087\tUBE2J2\tGene Expression\n',
#  'ENSG00000230415\tLINC01786\tGene Expression\n',
#  'ENSG00000162572\tSCNN1D\tGene Expression\n',
#  'ENSG00000131584\tACAP3\tGene Expression\n',
#  'ENSG00000169972\tPUSL1\tGene Expression\n',
#  'ENSG00000127054\tINTS11\tGene Expression\n',
#  'ENSG00000240731\tAL139287.1\tGene Expression\n',
#  'ENSG00000224051\tCPTP\tGene Expression\n',
#  'ENSG00000169962\tTAS1R3\tGene Expression\n',
#  'ENSG00000107404\tDVL1\tGene Expression\n',
#  'ENSG00000162576\tMXRA8\tGene Expression\n',
#  'ENSG00000175756\tAURKAIP1\tGene Expression\n',
#  'ENSG00000221978\tCCNL2\tGene Expression\n',
#  'ENSG00000224870\tMRPL20-AS1\tGene Expression\n',
#  'ENSG00000242485\tMRPL20\tGene Expression\n',
#  'ENSG00000272455\tAL391244.2\tGene Expression\n',
#  'ENSG00000235098\tANKRD65\tGene Expression\n',
#  'ENSG00000225905\tAL391244.1\tGene Expression\n',
#  'ENSG00000205116\tTMEM88B\tGene Expression\n',
#  'ENSG00000225285\tLINC01770\tGene Expression\n',
#  'ENSG00000179403\tVWA1\tGene Expression\n',
#  'ENSG00000215915\tATAD3C\tGene Expression\n',
#  'ENSG00000160072\tATAD3B\tGene Expression\n',
#  'ENSG00000197785\tATAD3A\tGene Expression\n',
#  'ENSG00000205090\tTMEM240\tGene Expression\n',
#  'ENSG00000160075\tSSU72\tGene Expression\n',
#  'ENSG00000215014\tAL645728.1\tGene Expression\n',
#  'ENSG00000228594\tFNDC10\tGene Expression\n',
#  'ENSG00000286989\tAL691432.4\tGene Expression\n',
#  'ENSG00000272106\tAL691432.2\tGene Expression\n',
#  'ENSG00000197530\tMIB2\tGene Expression\n',
#  'ENSG00000189409\tMMP23B\tGene Expression\n',
#  'ENSG00000248333\tCDK11B\tGene Expression\n',
#  'ENSG00000272004\tFO704657.1\tGene Expression\n',
#  'ENSG00000189339\tSLC35E2B\tGene Expression\n',
#  'ENSG00000008128\tCDK11A\tGene Expression\n',
#  'ENSG00000215790\tSLC35E2A\tGene Expression\n',
#  'ENSG00000008130\tNADK\tGene Expression\n',
#  'ENSG00000078369\tGNB1\tGene Expression\n',
#  'ENSG00000231050\tAL109917.1\tGene Expression\n',
#  'ENSG00000169885\tCALML6\tGene Expression\n',
#  'ENSG00000178821\tTMEM52\tGene Expression\n',
#  'ENSG00000142609\tCFAP74\tGene Expression\n',
#  'ENSG00000233542\tAL391845.2\tGene Expression\n',
#  'ENSG00000187730\tGABRD\tGene Expression\n',
#  'ENSG00000226969\tAL391845.1\tGene Expression\n',
#  'ENSG00000067606\tPRKCZ\tGene Expression\n',
#  'ENSG00000271806\tAL590822.2\tGene Expression\n',
#  'ENSG00000182873\tPRKCZ-AS1\tGene Expression\n',
#  'ENSG00000162585\tFAAP20\tGene Expression\n',
#  'ENSG00000234396\tAL590822.1\tGene Expression\n',
#  'ENSG00000157933\tSKI\tGene Expression\n',
#  'ENSG00000287356\tAL590822.3\tGene Expression\n',
#  'ENSG00000116151\tMORN1\tGene Expression\n',
#  'ENSG00000272161\tAL589739.1\tGene Expression\n',
#  'ENSG00000272420\tAL513477.2\tGene Expression\n',
#  'ENSG00000157916\tRER1\tGene Expression\n',
#  'ENSG00000157911\tPEX10\tGene Expression\n',
#  'ENSG00000149527\tPLCH2\tGene Expression\n',
#  'ENSG00000224387\tAL139246.1\tGene Expression\n',
#  'ENSG00000229393\tAL139246.4\tGene Expression\n',
#  'ENSG00000157881\tPANK4\tGene Expression\n',
#  'ENSG00000197921\tHES5\tGene Expression\n',
#  'ENSG00000272449\tAL139246.5\tGene Expression\n',
#  'ENSG00000238164\tTNFRSF14-AS1\tGene Expression\n',
#  'ENSG00000157873\tTNFRSF14\tGene Expression\n',
#  'ENSG00000228037\tAL139246.3\tGene Expression\n',
#  'ENSG00000157870\tPRXL2B\tGene Expression\n',
#  'ENSG00000142606\tMMEL1\tGene Expression\n',
#  'ENSG00000237058\tAL831784.1\tGene Expression\n',
#  'ENSG00000215912\tTTC34\tGene Expression\n',
#  'ENSG00000285945\tAC242022.2\tGene Expression\n',
#  'ENSG00000283259\tAC242022.1\tGene Expression\n',
#  'ENSG00000233234\tAL592464.2\tGene Expression\n',
#  'ENSG00000287396\tAL592464.3\tGene Expression\n',
#  'ENSG00000231630\tAL592464.1\tGene Expression\n',
#  'ENSG00000284745\tAL589702.1\tGene Expression\n',
#  'ENSG00000169717\tACTRT2\tGene Expression\n',
#  'ENSG00000177133\tPRDM16-DT\tGene Expression\n',
#  'ENSG00000142611\tPRDM16\tGene Expression\n',
#  'ENSG00000226286\tAL008733.1\tGene Expression\n',
#  'ENSG00000272235\tAL590438.1\tGene Expression\n',
#  'ENSG00000287828\tAL354743.2\tGene Expression\n',
#  'ENSG00000286518\tAL354743.1\tGene Expression\n',
#  'ENSG00000130762\tARHGEF16\tGene Expression\n',
#  'ENSG00000272088\tAL512413.1\tGene Expression\n',
#  'ENSG00000162591\tMEGF6\tGene Expression\n',
#  'ENSG00000238260\tAL513320.1\tGene Expression\n',
#  'ENSG00000158109\tTPRG1L\tGene Expression\n',
#  'ENSG00000116213\tWRAP73\tGene Expression\n',
#  'ENSG00000078900\tTP73\tGene Expression\n',
#  'ENSG00000227589\tAL136528.1\tGene Expression\n',
#  'ENSG00000235131\tAL136528.2\tGene Expression\n',
#  'ENSG00000162592\tCCDC27\tGene Expression\n',
#  'ENSG00000235169\tSMIM1\tGene Expression\n',
#  'ENSG00000130764\tLRRC47\tGene Expression\n',
#  'ENSG00000272153\tAL365330.1\tGene Expression\n',
#  'ENSG00000116198\tCEP104\tGene Expression\n',
#  'ENSG00000169598\tDFFB\tGene Expression\n',
#  'ENSG00000198912\tC1orf174\tGene Expression\n',
#  'ENSG00000236423\tLINC01134\tGene Expression\n',
#  'ENSG00000233304\tLINC01346\tGene Expression\n',
#  'ENSG00000226374\tLINC01345\tGene Expression\n',
#  'ENSG00000284668\tLINC02780\tGene Expression\n',
#  'ENSG00000284703\tAL805961.1\tGene Expression\n',
#  'ENSG00000235054\tLINC01777\tGene Expression\n',
#  'ENSG00000284694\tAL355602.1\tGene Expression\n',
#  'ENSG00000227169\tZ98747.1\tGene Expression\n',
#  'ENSG00000232596\tLINC01646\tGene Expression\n',
#  'ENSG00000196581\tAJAP1\tGene Expression\n',
#  'ENSG00000287586\tZ98886.1\tGene Expression\n',
#  'ENSG00000284739\tBX005132.1\tGene Expression\n',
#  'ENSG00000284674\tLINC02781\tGene Expression\n',
#  'ENSG00000231510\tLINC02782\tGene Expression\n',
#  'ENSG00000284616\tAL139823.1\tGene Expression\n',
#  'ENSG00000284692\tZ98259.3\tGene Expression\n',
#  'ENSG00000284666\tZ98259.2\tGene Expression\n',
#  'ENSG00000260972\tZ98259.1\tGene Expression\n',
#  'ENSG00000236948\tAL365255.1\tGene Expression\n',
#  'ENSG00000131697\tNPHP4\tGene Expression\n',
#  'ENSG00000069424\tKCNAB2\tGene Expression\n',
#  'ENSG00000116254\tCHD5\tGene Expression\n',
#  'ENSG00000116251\tRPL22\tGene Expression\n',
#  'ENSG00000226944\tAL031847.1\tGene Expression\n',
#  'ENSG00000158286\tRNF207\tGene Expression\n',
#  'ENSG00000116237\tICMT\tGene Expression\n',
#  'ENSG00000225077\tLINC00337\tGene Expression\n',
#  'ENSG00000173673\tHES3\tGene Expression\n',
#  'ENSG00000158292\tGPR153\tGene Expression\n',
#  'ENSG00000097021\tACOT7\tGene Expression\n',
#  'ENSG00000271746\tAL031848.2\tGene Expression\n',
#  'ENSG00000069812\tHES2\tGene Expression\n',
#  'ENSG00000187017\tESPN\tGene Expression\n',
#  'ENSG00000231868\tAL031848.1\tGene Expression\n',
#  'ENSG00000215788\tTNFRSF25\tGene Expression\n',
#  'ENSG00000171680\tPLEKHG5\tGene Expression\n',
#  'ENSG00000162408\tNOL9\tGene Expression\n',
#  'ENSG00000173662\tTAS1R1\tGene Expression\n',
#  'ENSG00000204859\tZBTB48\tGene Expression\n',
#  'ENSG00000162413\tKLHL21\tGene Expression\n',
#  'ENSG00000116273\tPHF13\tGene Expression\n',
#  'ENSG00000041988\tTHAP3\tGene Expression\n',
#  'ENSG00000007923\tDNAJC11\tGene Expression\n',
#  'ENSG00000228750\tLINC01672\tGene Expression\n',
#  'ENSG00000284744\tAL591163.1\tGene Expression\n',
#  'ENSG00000237436\tCAMTA1-DT\tGene Expression\n',
#  'ENSG00000171735\tCAMTA1\tGene Expression\n',
#  'ENSG00000237365\tAL512330.1\tGene Expression\n',
#  'ENSG00000237402\tCAMTA1-IT1\tGene Expression\n',
#  'ENSG00000237728\tZ97987.1\tGene Expression\n',
#  'ENSG00000225126\tAL365194.1\tGene Expression\n',
#  'ENSG00000270171\tAL359881.3\tGene Expression\n',
#  'ENSG00000270035\tAL359881.2\tGene Expression\n',
#  'ENSG00000269978\tAL359881.1\tGene Expression\n',
#  'ENSG00000049245\tVAMP3\tGene Expression\n',
#  'ENSG00000269925\tZ98884.2\tGene Expression\n',
#  'ENSG00000049246\tPER3\tGene Expression\n',
#  'ENSG00000236266\tZ98884.1\tGene Expression\n',
#  'ENSG00000049247\tUTS2\tGene Expression\n',
#  'ENSG00000049249\tTNFRSF9\tGene Expression\n',
#  'ENSG00000116288\tPARK7\tGene Expression\n',
#  'ENSG00000284747\tAL034417.4\tGene Expression\n',
#  'ENSG00000284716\tAL034417.3\tGene Expression\n',
#  'ENSG00000116285\tERRFI1\tGene Expression\n',
#  'ENSG00000238290\tAL034417.2\tGene Expression\n',
#  'ENSG00000227634\tLINC01714\tGene Expression\n',
#  'ENSG00000233645\tAL358876.2\tGene Expression\n',
#  'ENSG00000162426\tSLC45A1\tGene Expression\n',
#  'ENSG00000142599\tRERE\tGene Expression\n',
#  'ENSG00000232912\tRERE-AS1\tGene Expression\n',
#  'ENSG00000228423\tAL357552.2\tGene Expression\n',
#  'ENSG00000074800\tENO1\tGene Expression\n',
#  'ENSG00000230679\tENO1-AS1\tGene Expression\n',
#  'ENSG00000131686\tCA6\tGene Expression\n',
#  'ENSG00000197241\tSLC2A7\tGene Expression\n',
#  'ENSG00000142583\tSLC2A5\tGene Expression\n',
#  'ENSG00000180758\tGPR157\tGene Expression\n',
#  'ENSG00000228526\tMIR34AHG\tGene Expression\n',
#  'ENSG00000234546\tLNCTAM34A\tGene Expression\n',
#  'ENSG00000049239\tH6PD\tGene Expression\n',
#  'ENSG00000171621\tSPSB1\tGene Expression\n',
#  'ENSG00000284652\tBX323043.1\tGene Expression\n',
#  'ENSG00000284693\tLINC02606\tGene Expression\n',
#  'ENSG00000235263\tAL928921.1\tGene Expression\n',
#  'ENSG00000171612\tSLC25A33\tGene Expression\n',
#  'ENSG00000188807\tTMEM201\tGene Expression\n',
#  'ENSG00000171608\tPIK3CD\tGene Expression\n',
#  'ENSG00000179840\tPIK3CD-AS1\tGene Expression\n',
#  'ENSG00000231789\tPIK3CD-AS2\tGene Expression\n',
#  'ENSG00000171603\tCLSTN1\tGene Expression\n',
#  'ENSG00000178585\tCTNNBIP1\tGene Expression\n',
#  'ENSG00000223989\tAL357140.1\tGene Expression\n',
#  'ENSG00000285701\tAL357140.4\tGene Expression\n',
#  'ENSG00000162441\tLZIC\tGene Expression\n',
#  'ENSG00000228150\tAL357140.2\tGene Expression\n',
#  'ENSG00000173614\tNMNAT1\tGene Expression\n',
#  'ENSG00000241326\tAL603962.1\tGene Expression\n',
#  'ENSG00000162444\tRBP7\tGene Expression\n',
#  'ENSG00000130939\tUBE4B\tGene Expression\n',
#  'ENSG00000054523\tKIF1B\tGene Expression\n',
#  'ENSG00000284735\tAL139424.3\tGene Expression\n',
#  'ENSG00000284642\tAL139424.2\tGene Expression\n',
#  'ENSG00000142657\tPGD\tGene Expression\n',
#  'ENSG00000271989\tAL139424.1\tGene Expression\n',
#  'ENSG00000175279\tCENPS\tGene Expression\n',
#  'ENSG00000241563\tCORT\tGene Expression\n',
#  'ENSG00000160049\tDFFA\tGene Expression\n',
#  'ENSG00000203469\tAL354956.1\tGene Expression\n',
#  'ENSG00000142655\tPEX14\tGene Expression\n',
#  'ENSG00000287727\tAL139423.2\tGene Expression\n',
#  'ENSG00000130940\tCASZ1\tGene Expression\n',
#  'ENSG00000272078\tAL139423.1\tGene Expression\n',
#  'ENSG00000175262\tC1orf127\tGene Expression\n',
#  'ENSG00000120948\tTARDBP\tGene Expression\n',
#  'ENSG00000009724\tMASP2\tGene Expression\n',
#  'ENSG00000271895\tAL109811.2\tGene Expression\n',
#  'ENSG00000116649\tSRM\tGene Expression\n',
#  'ENSG00000171824\tEXOSC10\tGene Expression\n',
#  'ENSG00000226849\tAL109811.1\tGene Expression\n',
#  'ENSG00000230337\tEXOSC10-AS1\tGene Expression\n',
#  'ENSG00000198793\tMTOR\tGene Expression\n',
#  'ENSG00000225602\tMTOR-AS1\tGene Expression\n',
#  'ENSG00000171819\tANGPTL7\tGene Expression\n',
#  'ENSG00000120942\tUBIAD1\tGene Expression\n',
#  'ENSG00000284646\tAL031291.1\tGene Expression\n',
#  'ENSG00000204624\tDISP3\tGene Expression\n',
#  'ENSG00000285833\tAL590989.1\tGene Expression\n',
#  'ENSG00000235643\tLINC01647\tGene Expression\n',
#  'ENSG00000284708\tAL031731.1\tGene Expression\n',
#  'ENSG00000116661\tFBXO2\tGene Expression\n',
#  'ENSG00000132879\tFBXO44\tGene Expression\n',
#  'ENSG00000116663\tFBXO6\tGene Expression\n',
#  'ENSG00000116670\tMAD2L2\tGene Expression\n',
#  'ENSG00000162490\tDRAXIN\tGene Expression\n',
#  'ENSG00000177674\tAGTRAP\tGene Expression\n',
#  'ENSG00000215910\tC1orf167\tGene Expression\n',
#  'ENSG00000177553\tAL953897.1\tGene Expression\n',
#  'ENSG00000177000\tMTHFR\tGene Expression\n',
#  'ENSG00000011021\tCLCN6\tGene Expression\n',
#  'ENSG00000175206\tNPPA\tGene Expression\n',
#  'ENSG00000120937\tNPPB\tGene Expression\n',
#  'ENSG00000285646\tAL021155.5\tGene Expression\n',
#  'ENSG00000116685\tKIAA2013\tGene Expression\n',
#  'ENSG00000083444\tPLOD1\tGene Expression\n',
#  'ENSG00000287384\tAL096840.2\tGene Expression\n',
#  'ENSG00000116688\tMFN2\tGene Expression\n',
#  'ENSG00000116691\tMIIP\tGene Expression\n',
#  'ENSG00000120949\tTNFRSF8\tGene Expression\n',
#  'ENSG00000285604\tAL357835.1\tGene Expression\n',
#  'ENSG00000028137\tTNFRSF1B\tGene Expression\n',
#  'ENSG00000048707\tVPS13D\tGene Expression\n',
#  'ENSG00000229484\tLINC02766\tGene Expression\n',
#  'ENSG00000162496\tDHRS3\tGene Expression\n',
#  'ENSG00000272482\tAC254633.1\tGene Expression\n',
#  'ENSG00000204518\tAADACL4\tGene Expression\n',
#  'ENSG00000188984\tAADACL3\tGene Expression\n',
#  'ENSG00000157330\tC1orf158\tGene Expression\n',
#  'ENSG00000116726\tPRAMEF12\tGene Expression\n',
#  'ENSG00000116721\tPRAMEF1\tGene Expression\n',
#  'ENSG00000228338\tLINC01784\tGene Expression\n',
#  'ENSG00000239810\tPRAMEF11\tGene Expression\n',
#  'ENSG00000179172\tHNRNPCL1\tGene Expression\n',
#  'ENSG00000120952\tPRAMEF2\tGene Expression\n',
#  'ENSG00000243073\tPRAMEF4\tGene Expression\n',
#  'ENSG00000187545\tPRAMEF10\tGene Expression\n',
#  'ENSG00000204510\tPRAMEF7\tGene Expression\n',
#  'ENSG00000232423\tPRAMEF6\tGene Expression\n',
#  'ENSG00000274764\tPRAMEF27\tGene Expression\n',
#  'ENSG00000277058\tHNRNPCL3\tGene Expression\n',
#  'ENSG00000229571\tPRAMEF25\tGene Expression\n',
#  'ENSG00000275774\tHNRNPCL2\tGene Expression\n',
#  'ENSG00000233336\tAC245056.1\tGene Expression\n',
#  'ENSG00000280267\tPRAMEF26\tGene Expression\n',
#  'ENSG00000179412\tHNRNPCL4\tGene Expression\n',
#  'ENSG00000204505\tPRAMEF9\tGene Expression\n',
#  'ENSG00000279169\tPRAMEF13\tGene Expression\n',
#  'ENSG00000279804\tPRAMEF18\tGene Expression\n',
#  'ENSG00000270601\tPRAMEF5\tGene Expression\n',
#  'ENSG00000182330\tPRAMEF8\tGene Expression\n',
#  'ENSG00000237700\tPRAMEF33\tGene Expression\n',
#  'ENSG00000204501\tPRAMEF15\tGene Expression\n',
#  'ENSG00000228229\tAC243961.1\tGene Expression\n',
#  'ENSG00000204481\tPRAMEF14\tGene Expression\n',
#  'ENSG00000204480\tPRAMEF19\tGene Expression\n',
#  'ENSG00000204479\tPRAMEF17\tGene Expression\n',
#  'ENSG00000204478\tPRAMEF20\tGene Expression\n',
#  'ENSG00000162494\tLRRC38\tGene Expression\n',
#  'ENSG00000259961\tAL354712.1\tGene Expression\n',
#  'ENSG00000162493\tPDPN\tGene Expression\n',
#  'ENSG00000237445\tAL359771.1\tGene Expression\n',
#  'ENSG00000116731\tPRDM2\tGene Expression\n',
#  'ENSG00000189337\tKAZN\tGene Expression\n',
#  'ENSG00000231606\tAL357873.1\tGene Expression\n',
#  'ENSG00000234593\tKAZN-AS1\tGene Expression\n',
#  'ENSG00000287756\tAL031293.1\tGene Expression\n',
#  'ENSG00000175147\tTMEM51-AS1\tGene Expression\n',
#  'ENSG00000171729\tTMEM51\tGene Expression\n',
#  'ENSG00000204464\tC1orf195\tGene Expression\n',
#  'ENSG00000142621\tFHAD1\tGene Expression\n',
#  'ENSG00000233485\tAL031283.2\tGene Expression\n',
#  'ENSG00000236045\tAL031283.3\tGene Expression\n',
#  'ENSG00000228140\tAL031283.1\tGene Expression\n',
#  'ENSG00000142634\tEFHD2\tGene Expression\n',
#  'ENSG00000162438\tCTRC\tGene Expression\n',
#  'ENSG00000142615\tCELA2A\tGene Expression\n',
#  'ENSG00000215704\tCELA2B\tGene Expression\n',
#  'ENSG00000132906\tCASP9\tGene Expression\n',
#  'ENSG00000116138\tDNAJC16\tGene Expression\n',
#  'ENSG00000272510\tAL121992.3\tGene Expression\n',
#  'ENSG00000116771\tAGMAT\tGene Expression\n',
#  'ENSG00000237301\tAL121992.1\tGene Expression\n',
#  'ENSG00000197312\tDDI2\tGene Expression\n',
#  'ENSG00000215695\tRSC1A1\tGene Expression\n',
#  'ENSG00000271742\tAL121992.2\tGene Expression\n',
#  'ENSG00000116786\tPLEKHM2\tGene Expression\n',
#  'ENSG00000237938\tAL450998.3\tGene Expression\n',
#  'ENSG00000162461\tSLC25A34\tGene Expression\n',
#  'ENSG00000224459\tSLC25A34-AS1\tGene Expression\n',
#  'ENSG00000162460\tTMEM82\tGene Expression\n',
#  'ENSG00000162458\tFBLIM1\tGene Expression\n',
#  'ENSG00000233954\tUQCRHL\tGene Expression\n',
#  'ENSG00000179743\tAL450998.2\tGene Expression\n',
#  'ENSG00000065526\tSPEN\tGene Expression\n',
#  'ENSG00000116809\tZBTB17\tGene Expression\n',
#  'ENSG00000183888\tSRARP\tGene Expression\n',
#  'ENSG00000233078\tAL355994.3\tGene Expression\n',
#  'ENSG00000173641\tHSPB7\tGene Expression\n',
#  'ENSG00000186510\tCLCNKA\tGene Expression\n',
#  'ENSG00000184908\tCLCNKB\tGene Expression\n',
#  'ENSG00000185519\tFAM131C\tGene Expression\n',
#  'ENSG00000142627\tEPHA2\tGene Expression\n',
#  'ENSG00000227959\tAL451042.2\tGene Expression\n',
#  'ENSG00000224621\tAL451042.1\tGene Expression\n',
#  'ENSG00000234166\tARHGEF19-AS1\tGene Expression\n',
#  'ENSG00000142632\tARHGEF19\tGene Expression\n',
#  'ENSG00000288398\tAL109627.1\tGene Expression\n',
#  'ENSG00000132881\tCPLANE2\tGene Expression\n',
#  'ENSG00000037637\tFBXO42\tGene Expression\n',
#  'ENSG00000055070\tSZRD1\tGene Expression\n',
#  'ENSG00000187144\tSPATA21\tGene Expression\n',
#  'ENSG00000157191\tNECAP2\tGene Expression\n',
#  'ENSG00000226029\tLINC01772\tGene Expression\n',
#  'ENSG00000261135\tAL137802.2\tGene Expression\n',
#  'ENSG00000224174\tAL137802.1\tGene Expression\n',
#  'ENSG00000233421\tLINC01783\tGene Expression\n',
#  'ENSG00000219481\tNBPF1\tGene Expression\n',
#  'ENSG00000271732\tAL137798.1\tGene Expression\n',
#  'ENSG00000282143\tAL137798.2\tGene Expression\n',
#  'ENSG00000279151\tAL021920.1\tGene Expression\n',
#  'ENSG00000282740\tAL021920.3\tGene Expression\n',
#  'ENSG00000058453\tCROCC\tGene Expression\n',
#  'ENSG00000223643\tBX284668.1\tGene Expression\n',
#  'ENSG00000228549\tBX284668.2\tGene Expression\n',
#  'ENSG00000238142\tBX284668.5\tGene Expression\n',
#  'ENSG00000272426\tBX284668.6\tGene Expression\n',
#  'ENSG00000117122\tMFAP2\tGene Expression\n',
#  'ENSG00000286898\tAL049569.2\tGene Expression\n',
#  'ENSG00000226526\tAL049569.1\tGene Expression\n',
#  'ENSG00000159363\tATP13A2\tGene Expression\n',
#  'ENSG00000117118\tSDHB\tGene Expression\n',
#  'ENSG00000117115\tPADI2\tGene Expression\n',
#  'ENSG00000204362\tLINC02783\tGene Expression\n',
#  'ENSG00000282843\tAL590644.1\tGene Expression\n',
#  'ENSG00000142623\tPADI1\tGene Expression\n',
#  'ENSG00000142619\tPADI3\tGene Expression\n',
#  'ENSG00000159339\tPADI4\tGene Expression\n',
#  'ENSG00000276747\tPADI6\tGene Expression\n',
#  'ENSG00000227751\tRCC2-AS1\tGene Expression\n',
#  'ENSG00000179051\tRCC2\tGene Expression\n',
#  'ENSG00000074964\tARHGEF10L\tGene Expression\n',
#  'ENSG00000236648\tLINC02810\tGene Expression\n',
#  'ENSG00000117148\tACTL8\tGene Expression\n',
#  'ENSG00000284653\tAL357509.1\tGene Expression\n',
#  'ENSG00000261781\tLINC01654\tGene Expression\n',
#  'ENSG00000117154\tIGSF21\tGene Expression\n',
#  'ENSG00000230035\tIGSF21-AS1\tGene Expression\n',
#  'ENSG00000225387\tAL591896.1\tGene Expression\n',
#  'ENSG00000179023\tKLHDC7A\tGene Expression\n',
#  'ENSG00000009709\tPAX7\tGene Expression\n',
#  'ENSG00000179002\tTAS1R2\tGene Expression\n',
#  'ENSG00000159423\tALDH4A1\tGene Expression\n',
#  'ENSG00000169991\tIFFO2\tGene Expression\n',
#  'ENSG00000272084\tAL137127.1\tGene Expression\n',
#  'ENSG00000127481\tUBR4\tGene Expression\n',
#  'ENSG00000230424\tEMC1-AS1\tGene Expression\n',
#  'ENSG00000127463\tEMC1\tGene Expression\n',
#  'ENSG00000053372\tMRTO4\tGene Expression\n',
#  'ENSG00000162482\tAKR7A3\tGene Expression\n',
#  'ENSG00000053371\tAKR7A2\tGene Expression\n',
#  'ENSG00000040487\tSLC66A1\tGene Expression\n',
#  'ENSG00000077549\tCAPZB\tGene Expression\n',
#  'ENSG00000173436\tMICOS10\tGene Expression\n',
#  'ENSG00000235185\tAL031727.2\tGene Expression\n',
#  'ENSG00000158747\tNBL1\tGene Expression\n',
#  'ENSG00000158748\tHTR6\tGene Expression\n',
#  'ENSG00000162542\tTMCO4\tGene Expression\n',
#  'ENSG00000178828\tRNF186\tGene Expression\n',
#  'ENSG00000235434\tAL391883.1\tGene Expression\n',
#  'ENSG00000169914\tOTUD3\tGene Expression\n',
#  'ENSG00000188784\tPLA2G2E\tGene Expression\n',
#  'ENSG00000188257\tPLA2G2A\tGene Expression\n',
#  'ENSG00000127472\tPLA2G5\tGene Expression\n',
#  'ENSG00000117215\tPLA2G2D\tGene Expression\n',
#  'ENSG00000158786\tPLA2G2F\tGene Expression\n',
#  'ENSG00000227066\tZ98257.1\tGene Expression\n',
#  'ENSG00000187980\tPLA2G2C\tGene Expression\n',
#  'ENSG00000225986\tUBXN10-AS1\tGene Expression\n',
#  'ENSG00000162543\tUBXN10\tGene Expression\n',
#  'ENSG00000228105\tLINC01757\tGene Expression\n',
#  'ENSG00000284710\tZ98257.2\tGene Expression\n',
#  'ENSG00000158816\tVWA5B1\tGene Expression\n',
#  'ENSG00000226664\tAL020998.1\tGene Expression\n',
#  'ENSG00000236963\tLINC01141\tGene Expression\n',
#  'ENSG00000226487\tAL139254.1\tGene Expression\n',
#  'ENSG00000284641\tAL139254.2\tGene Expression\n',
#  'ENSG00000284743\tAL139254.3\tGene Expression\n',
#  'ENSG00000162545\tCAMK2N1\tGene Expression\n',
#  'ENSG00000090432\tMUL1\tGene Expression\n',
#  'ENSG00000183114\tFAM43B\tGene Expression\n',
#  'ENSG00000158825\tCDA\tGene Expression\n',
#  'ENSG00000158828\tPINK1\tGene Expression\n',
#  'ENSG00000117242\tPINK1-AS\tGene Expression\n',
#  'ENSG00000244038\tDDOST\tGene Expression\n',
#  'ENSG00000117245\tKIF17\tGene Expression\n',
#  'ENSG00000189410\tSH2D5\tGene Expression\n',
#  'ENSG00000233069\tAL663074.1\tGene Expression\n',
#  'ENSG00000127483\tHP1BP3\tGene Expression\n',
#  'ENSG00000075151\tEIF4G3\tGene Expression\n',
#  'ENSG00000287192\tAL031005.2\tGene Expression\n',
#  'ENSG00000117298\tECE1\tGene Expression\n',
#  'ENSG00000236936\tAL031005.1\tGene Expression\n',
#  'ENSG00000231105\tAL031728.1\tGene Expression\n',
#  'ENSG00000236009\tAL592309.2\tGene Expression\n',
#  'ENSG00000142794\tNBPF3\tGene Expression\n',
#  'ENSG00000162551\tALPL\tGene Expression\n',
#  'ENSG00000233431\tLINC02596\tGene Expression\n',
#  'ENSG00000076864\tRAP1GAP\tGene Expression\n',
#  'ENSG00000090686\tUSP48\tGene Expression\n',
#  'ENSG00000187942\tLDLRAD2\tGene Expression\n',
#  'ENSG00000142798\tHSPG2\tGene Expression\n',
#  'ENSG00000219073\tCELA3B\tGene Expression\n',
#  'ENSG00000142789\tCELA3A\tGene Expression\n',
#  'ENSG00000228397\tLINC01635\tGene Expression\n',
#  'ENSG00000218510\tLINC00339\tGene Expression\n',
#  'ENSG00000070831\tCDC42\tGene Expression\n',
#  'ENSG00000285752\tCDC42-AS1\tGene Expression\n',
#  'ENSG00000230068\tCDC42-IT1\tGene Expression\n',
#  'ENSG00000162552\tWNT4\tGene Expression\n',
#  'ENSG00000285873\tAL445253.1\tGene Expression\n',
#  'ENSG00000184677\tZBTB40\tGene Expression\n',
#  'ENSG00000237200\tZBTB40-IT1\tGene Expression\n',
#  'ENSG00000070886\tEPHA8\tGene Expression\n',
#  'ENSG00000173372\tC1QA\tGene Expression\n',
#  'ENSG00000159189\tC1QC\tGene Expression\n',
#  'ENSG00000173369\tC1QB\tGene Expression\n',
#  'ENSG00000133216\tEPHB2\tGene Expression\n',
#  'ENSG00000225952\tAL512444.1\tGene Expression\n',
#  'ENSG00000215906\tLACTBL1\tGene Expression\n',
#  'ENSG00000227868\tTEX46\tGene Expression\n',
#  'ENSG00000004487\tKDM1A\tGene Expression\n',
#  'ENSG00000240553\tAL031428.1\tGene Expression\n',
#  'ENSG00000169641\tLUZP1\tGene Expression\n',
#  'ENSG00000179546\tHTR1D\tGene Expression\n',
#  'ENSG00000261326\tLINC01355\tGene Expression\n',
#  'ENSG00000284726\tAL109936.6\tGene Expression\n',
#  'ENSG00000125944\tHNRNPR\tGene Expression\n',
#  'ENSG00000125945\tZNF436\tGene Expression\n',
#  'ENSG00000249087\tZNF436-AS1\tGene Expression\n',
#  'ENSG00000271420\tAL109936.2\tGene Expression\n',
#  'ENSG00000204219\tTCEA3\tGene Expression\n',
#  'ENSG00000088280\tASAP3\tGene Expression\n',
#  'ENSG00000007968\tE2F2\tGene Expression\n',
#  'ENSG00000235052\tAL021154.1\tGene Expression\n',
#  'ENSG00000117318\tID3\tGene Expression\n',
#  'ENSG00000285802\tAL450043.1\tGene Expression\n',
#  'ENSG00000197880\tMDS2\tGene Expression\n',
#  'ENSG00000142676\tRPL11\tGene Expression\n',
#  'ENSG00000236810\tELOA-AS1\tGene Expression\n',
#  'ENSG00000011007\tELOA\tGene Expression\n',
#  'ENSG00000057757\tPITHD1\tGene Expression\n',
#  'ENSG00000011009\tLYPLA2\tGene Expression\n',
#  'ENSG00000117308\tGALE\tGene Expression\n',
#  'ENSG00000117305\tHMGCL\tGene Expression\n',
#  'ENSG00000179163\tFUCA1\tGene Expression\n',
#  'ENSG00000188822\tCNR2\tGene Expression\n',
#  'ENSG00000232557\tAL590609.3\tGene Expression\n',
#  'ENSG00000189266\tPNRC2\tGene Expression\n',
#  'ENSG00000188529\tSRSF10\tGene Expression\n',
#  'ENSG00000225315\tAL591178.1\tGene Expression\n',
#  'ENSG00000142661\tMYOM3\tGene Expression\n',
#  'ENSG00000230703\tAL591178.2\tGene Expression\n',
#  'ENSG00000142677\tIL22RA1\tGene Expression\n',
#  'ENSG00000185436\tIFNLR1\tGene Expression\n',
#  'ENSG00000230023\tLINC02800\tGene Expression\n',
#  'ENSG00000232298\tAL138902.1\tGene Expression\n',
#  'ENSG00000158055\tGRHL3\tGene Expression\n',
#  'ENSG00000001460\tSTPG1\tGene Expression\n',
#  'ENSG00000001461\tNIPAL3\tGene Expression\n',
#  'ENSG00000286061\tRCAN3AS\tGene Expression\n',
#  'ENSG00000117602\tRCAN3\tGene Expression\n',
#  'ENSG00000264443\tNCMAP-DT\tGene Expression\n',
#  'ENSG00000184454\tNCMAP\tGene Expression\n',
#  'ENSG00000133226\tSRRM1\tGene Expression\n',
#  'ENSG00000284699\tAL445648.1\tGene Expression\n',
#  'ENSG00000169504\tCLIC4\tGene Expression\n',
#  'ENSG00000020633\tRUNX3\tGene Expression\n',
#  'ENSG00000229162\tAL445471.1\tGene Expression\n',
#  'ENSG00000261025\tAL445471.2\tGene Expression\n',
#  'ENSG00000285823\tLINC02793\tGene Expression\n',
#  'ENSG00000233755\tAL050344.1\tGene Expression\n',
#  'ENSG00000231953\tAL031432.1\tGene Expression\n',
#  'ENSG00000117614\tSYF2\tGene Expression\n',
#  'ENSG00000284602\tAL031432.4\tGene Expression\n',
#  'ENSG00000284657\tAL031432.5\tGene Expression\n',
#  'ENSG00000117616\tRSRP1\tGene Expression\n',
#  'ENSG00000272432\tAL031432.3\tGene Expression\n',
#  'ENSG00000187010\tRHD\tGene Expression\n',
#  'ENSG00000183726\tTMEM50A\tGene Expression\n',
#  'ENSG00000188672\tRHCE\tGene Expression\n',
#  'ENSG00000204178\tMACO1\tGene Expression\n',
#  'ENSG00000157978\tLDLRAP1\tGene Expression\n',
#  'ENSG00000225643\tAL606491.1\tGene Expression\n',
#  'ENSG00000117643\tMAN1C1\tGene Expression\n',
#  'ENSG00000233478\tAL031280.1\tGene Expression\n',
#  'ENSG00000162430\tSELENON\tGene Expression\n',
#  'ENSG00000228172\tAL020996.1\tGene Expression\n',
#  'ENSG00000117640\tMTFR1L\tGene Expression\n',
#  'ENSG00000272478\tAL020996.3\tGene Expression\n',
#  'ENSG00000127423\tAUNIP\tGene Expression\n',
#  'ENSG00000236528\tAL033528.2\tGene Expression\n',
#  'ENSG00000182749\tPAQR7\tGene Expression\n',
#  'ENSG00000117632\tSTMN1\tGene Expression\n',
#  'ENSG00000158006\tPAFAH2\tGene Expression\n',
#  'ENSG00000158008\tEXTL1\tGene Expression\n',
#  'ENSG00000158014\tSLC30A2\tGene Expression\n',
#  'ENSG00000284309\tAL391650.2\tGene Expression\n',
#  'ENSG00000158022\tTRIM63\tGene Expression\n',
#  'ENSG00000175087\tPDIK1L\tGene Expression\n',
#  'ENSG00000197245\tFAM110D\tGene Expression\n',
#  'ENSG00000282872\tC1orf232\tGene Expression\n',
#  'ENSG00000236782\tAL391650.1\tGene Expression\n',
#  'ENSG00000142684\tZNF593\tGene Expression\n',
#  'ENSG00000142675\tCNKSR1\tGene Expression\n',
#  'ENSG00000188782\tCATSPER4\tGene Expression\n',
#  'ENSG00000130695\tCEP85\tGene Expression\n',
#  'ENSG00000142669\tSH3BGRL3\tGene Expression\n',
#  'ENSG00000158062\tUBXN11\tGene Expression\n',
#  'ENSG00000169442\tCD52\tGene Expression\n',
#  'ENSG00000176092\tCRYBG2\tGene Expression\n',
#  'ENSG00000176083\tZNF683\tGene Expression\n',
#  'ENSG00000131914\tLIN28A\tGene Expression\n',
#  'ENSG00000117682\tDHDDS\tGene Expression\n',
#  'ENSG00000225891\tAL513365.2\tGene Expression\n',
#  'ENSG00000198830\tHMGN2\tGene Expression\n',
#  'ENSG00000117676\tRPS6KA1\tGene Expression\n',
#  'ENSG00000260063\tAL512408.1\tGene Expression\n',
#  'ENSG00000117713\tARID1A\tGene Expression\n',
#  'ENSG00000060642\tPIGV\tGene Expression\n',
#  'ENSG00000204160\tZDHHC18\tGene Expression\n',
#  'ENSG00000175793\tSFN\tGene Expression\n',
#  'ENSG00000142751\tGPN2\tGene Expression\n',
#  'ENSG00000226698\tAL034380.1\tGene Expression\n',
#  'ENSG00000198746\tGPATCH3\tGene Expression\n',
#  'ENSG00000090273\tNUDC\tGene Expression\n',
#  'ENSG00000131910\tNR0B2\tGene Expression\n',
#  'ENSG00000175707\tKDF1\tGene Expression\n',
#  'ENSG00000253368\tTRNP1\tGene Expression\n',
#  'ENSG00000158246\tTENT5B\tGene Expression\n',
#  'ENSG00000090020\tSLC9A1\tGene Expression\n',
#  'ENSG00000224311\tAL590640.1\tGene Expression\n',
#  'ENSG00000142784\tWDTC1\tGene Expression\n',
#  'ENSG00000186501\tTMEM222\tGene Expression\n',
#  'ENSG00000142765\tSYTL1\tGene Expression\n',
#  'ENSG00000142733\tMAP3K6\tGene Expression\n',
#  'ENSG00000142748\tFCN3\tGene Expression\n',
#  'ENSG00000174950\tCD164L2\tGene Expression\n',
#  'ENSG00000181773\tGPR3\tGene Expression\n',
#  'ENSG00000158195\tWASF2\tGene Expression\n',
#  'ENSG00000241169\tFO393419.2\tGene Expression\n',
#  'ENSG00000237429\tBX293535.1\tGene Expression\n',
#  'ENSG00000126705\tAHDC1\tGene Expression\n',
#  'ENSG00000000938\tFGR\tGene Expression\n',
#  'ENSG00000233975\tLINC02574\tGene Expression\n',
#  'ENSG00000126709\tIFI6\tGene Expression\n',
#  'ENSG00000225886\tAL445490.1\tGene Expression\n',
#  'ENSG00000287244\tAL020997.5\tGene Expression\n',
#  'ENSG00000009780\tFAM76A\tGene Expression\n',
#  'ENSG00000117758\tSTX12\tGene Expression\n',
#  'ENSG00000269971\tAL020997.2\tGene Expression\n',
#  'ENSG00000270031\tAL020997.3\tGene Expression\n',
#  'ENSG00000286433\tAL020997.4\tGene Expression\n',
#  'ENSG00000117751\tPPP1R8\tGene Expression\n',
#  'ENSG00000130775\tTHEMIS2\tGene Expression\n',
#  'ENSG00000117748\tRPA2\tGene Expression\n',
#  'ENSG00000130768\tSMPDL3B\tGene Expression\n',
#  'ENSG00000227050\tAL512288.1\tGene Expression\n',
#  'ENSG00000158156\tXKR8\tGene Expression\n',
#  'ENSG00000158161\tEYA3\tGene Expression\n',
#  'ENSG00000169403\tPTAFR\tGene Expression\n',
#  'ENSG00000126698\tDNAJC8\tGene Expression\n',
#  'ENSG00000130770\tATP5IF1\tGene Expression\n',
#  'ENSG00000270605\tAL353622.1\tGene Expression\n',
#  'ENSG00000271398\tAL353622.2\tGene Expression\n',
#  'ENSG00000130766\tSESN2\tGene Expression\n',
#  'ENSG00000130772\tMED18\tGene Expression\n',
#  'ENSG00000204138\tPHACTR4\tGene Expression\n',
#  'ENSG00000180198\tRCC1\tGene Expression\n',
#  'ENSG00000242125\tSNHG3\tGene Expression\n',
#  'ENSG00000180098\tTRNAU1AP\tGene Expression\n',
#  'ENSG00000197989\tSNHG12\tGene Expression\n',
#  'ENSG00000120656\tTAF12\tGene Expression\n',
#  'ENSG00000188060\tRAB42\tGene Expression\n',
#  'ENSG00000229388\tLINC01715\tGene Expression\n',
#  'ENSG00000270103\tAL360012.1\tGene Expression\n',
#  'ENSG00000162419\tGMEB1\tGene Expression\n',
#  'ENSG00000198492\tYTHDF2\tGene Expression\n',
#  'ENSG00000116329\tOPRD1\tGene Expression\n',
#  'ENSG00000233427\tAL009181.1\tGene Expression\n',
#  'ENSG00000159023\tEPB41\tGene Expression\n',
#  'ENSG00000253304\tTMEM200B\tGene Expression\n',
#  'ENSG00000225750\tAL357500.1\tGene Expression\n',
#  'ENSG00000116350\tSRSF4\tGene Expression\n',
#  'ENSG00000116353\tMECR\tGene Expression\n',
#  'ENSG00000237934\tAL590729.1\tGene Expression\n',
#  'ENSG00000060656\tPTPRU\tGene Expression\n',
#  'ENSG00000230523\tLINC01756\tGene Expression\n',
#  'ENSG00000228176\tAC092265.1\tGene Expression\n',
#  'ENSG00000284676\tAL645944.2\tGene Expression\n',
#  'ENSG00000233399\tLINC01648\tGene Expression\n',
#  'ENSG00000233372\tAL137076.1\tGene Expression\n',
#  'ENSG00000236335\tAL161638.2\tGene Expression\n',
#  'ENSG00000231949\tAL161638.1\tGene Expression\n',
#  'ENSG00000162510\tMATN1\tGene Expression\n',
#  'ENSG00000186056\tMATN1-AS1\tGene Expression\n',
#  'ENSG00000287510\tAL137857.1\tGene Expression\n',
#  'ENSG00000162511\tLAPTM5\tGene Expression\n',
#  'ENSG00000229607\tAL137027.1\tGene Expression\n',
#  'ENSG00000223382\tLINC01778\tGene Expression\n',
#  'ENSG00000235143\tAL445235.1\tGene Expression\n',
#  'ENSG00000162512\tSDC3\tGene Expression\n',
#  'ENSG00000134644\tPUM1\tGene Expression\n',
#  'ENSG00000084628\tNKAIN1\tGene Expression\n',
#  'ENSG00000060688\tSNRNP40\tGene Expression\n',
#  'ENSG00000121766\tZCCHC17\tGene Expression\n',
#  'ENSG00000229044\tAL451070.1\tGene Expression\n',
#  'ENSG00000121769\tFABP3\tGene Expression\n',
#  'ENSG00000168528\tSERINC2\tGene Expression\n',
#  'ENSG00000284543\tLINC01226\tGene Expression\n',
#  'ENSG00000229167\tAC114488.1\tGene Expression\n',
#  'ENSG00000142910\tTINAGL1\tGene Expression\n',
#  'ENSG00000121764\tHCRTR1\tGene Expression\n',
#  'ENSG00000162517\tPEF1\tGene Expression\n',
#  'ENSG00000235790\tAC114488.2\tGene Expression\n',
#  'ENSG00000264078\tAC114488.3\tGene Expression\n',
#  'ENSG00000084636\tCOL16A1\tGene Expression\n',
#  'ENSG00000121753\tADGRB2\tGene Expression\n',
#  'ENSG00000254545\tAL354919.2\tGene Expression\n',
#  'ENSG00000134668\tSPOCD1\tGene Expression\n',
#  'ENSG00000203620\tAL354919.1\tGene Expression\n',
#  'ENSG00000269967\tAL136115.2\tGene Expression\n',
#  'ENSG00000184007\tPTP4A2\tGene Expression\n',
#  'ENSG00000228634\tAL136115.1\tGene Expression\n',
#  'ENSG00000284702\tAL136115.3\tGene Expression\n',
#  'ENSG00000121774\tKHDRBS1\tGene Expression\n',
#  'ENSG00000203325\tAL445248.1\tGene Expression\n',
#  'ENSG00000121775\tTMEM39B\tGene Expression\n',
#  'ENSG00000025800\tKPNA6\tGene Expression\n',
#  'ENSG00000250135\tAL049795.2\tGene Expression\n',
#  'ENSG00000084652\tTXLNA\tGene Expression\n',
#  'ENSG00000160050\tCCDC28B\tGene Expression\n',
#  'ENSG00000224066\tAL049795.1\tGene Expression\n',
#  'ENSG00000160051\tIQCC\tGene Expression\n',
#  'ENSG00000222046\tDCDC2B\tGene Expression\n',
#  'ENSG00000160055\tTMEM234\tGene Expression\n',
#  'ENSG00000084623\tEIF3I\tGene Expression\n',
#  'ENSG00000183615\tFAM167B\tGene Expression\n',
#  'ENSG00000182866\tLCK\tGene Expression\n',
#  'ENSG00000116478\tHDAC1\tGene Expression\n',
#  'ENSG00000175130\tMARCKSL1\tGene Expression\n',
#  'ENSG00000233775\tAL109945.1\tGene Expression\n',
#  'ENSG00000162526\tTSSK3\tGene Expression\n',
#  'ENSG00000225828\tFAM229A\tGene Expression\n',
#  'ENSG00000160058\tBSDC1\tGene Expression\n',
#  'ENSG00000273274\tZBTB8B\tGene Expression\n',
#  'ENSG00000160062\tZBTB8A\tGene Expression\n',
#  'ENSG00000176261\tZBTB8OS\tGene Expression\n',
#  'ENSG00000162521\tRBBP4\tGene Expression\n',
#  'ENSG00000162520\tSYNC\tGene Expression\n',
#  'ENSG00000224409\tAC114489.1\tGene Expression\n',
#  'ENSG00000162522\tKIAA1522\tGene Expression\n',
#  'ENSG00000134684\tYARS\tGene Expression\n',
#  'ENSG00000116497\tS100PBP\tGene Expression\n',
#  'ENSG00000160097\tFNDC5\tGene Expression\n',
#  'ENSG00000121905\tHPCA\tGene Expression\n',
#  'ENSG00000121900\tTMEM54\tGene Expression\n',
#  'ENSG00000287691\tAL031602.2\tGene Expression\n',
#  'ENSG00000116514\tRNF19B\tGene Expression\n',
#  'ENSG00000236065\tAL020995.1\tGene Expression\n',
#  'ENSG00000004455\tAK2\tGene Expression\n',
#  'ENSG00000142920\tAZIN2\tGene Expression\n',
#  'ENSG00000116525\tTRIM62\tGene Expression\n',
#  'ENSG00000284721\tAL662907.3\tGene Expression\n',
#  'ENSG00000160094\tZNF362\tGene Expression\n',
#  'ENSG00000270115\tAL513327.3\tGene Expression\n',
#  'ENSG00000184389\tA3GALT2\tGene Expression\n',
#  'ENSG00000225313\tAL513327.1\tGene Expression\n',
#  'ENSG00000134686\tPHC2\tGene Expression\n',
#  'ENSG00000233246\tAL513327.2\tGene Expression\n',
#  'ENSG00000121903\tZSCAN20\tGene Expression\n',
#  'ENSG00000121904\tCSMD2\tGene Expression\n',
#  'ENSG00000176256\tHMGB4\tGene Expression\n',
#  'ENSG00000231163\tCSMD2-AS1\tGene Expression\n',
#  'ENSG00000142698\tC1orf94\tGene Expression\n',
#  'ENSG00000287703\tAC099565.1\tGene Expression\n',
#  'ENSG00000163866\tSMIM12\tGene Expression\n',
#  'ENSG00000189280\tGJB5\tGene Expression\n',
#  'ENSG00000189433\tGJB4\tGene Expression\n',
#  'ENSG00000255811\tAL121988.1\tGene Expression\n',
#  'ENSG00000188910\tGJB3\tGene Expression\n',
#  'ENSG00000187513\tGJA4\tGene Expression\n',
#  'ENSG00000230163\tAL122010.1\tGene Expression\n',
#  'ENSG00000116544\tDLGAP3\tGene Expression\n',
#  'ENSG00000243749\tTMEM35B\tGene Expression\n',
#  'ENSG00000163867\tZMYM6\tGene Expression\n',
#  'ENSG00000197056\tZMYM1\tGene Expression\n',
#  'ENSG00000284640\tAL590434.1\tGene Expression\n',
#  'ENSG00000116560\tSFPQ\tGene Expression\n',
#  'ENSG00000146463\tZMYM4\tGene Expression\n',
#  'ENSG00000227409\tZMYM4-AS1\tGene Expression\n',
#  'ENSG00000142687\tKIAA0319L\tGene Expression\n',
#  'ENSG00000020129\tNCDN\tGene Expression\n',
#  'ENSG00000239636\tAC004865.2\tGene Expression\n',
#  'ENSG00000116819\tTFAP2E\tGene Expression\n',
#  'ENSG00000126067\tPSMB2\tGene Expression\n',
#  'ENSG00000142686\tC1orf216\tGene Expression\n',
#  'ENSG00000092853\tCLSPN\tGene Expression\n',
#  'ENSG00000232335\tAL354864.1\tGene Expression\n',
#  'ENSG00000134698\tAGO4\tGene Expression\n',
#  'ENSG00000092847\tAGO1\tGene Expression\n',
#  'ENSG00000286899\tAL139286.3\tGene Expression\n',
#  'ENSG00000271914\tAL139286.2\tGene Expression\n',
#  'ENSG00000126070\tAGO3\tGene Expression\n',
#  'ENSG00000271554\tAL138787.2\tGene Expression\n',
#  'ENSG00000092850\tTEKT2\tGene Expression\n',
#  'ENSG00000116863\tADPRHL2\tGene Expression\n',
#  'ENSG00000171812\tCOL8A2\tGene Expression\n',
#  'ENSG00000054116\tTRAPPC3\tGene Expression\n',
#  'ENSG00000116871\tMAP7D1\tGene Expression\n',
#  'ENSG00000054118\tTHRAP3\tGene Expression\n',
#  'ENSG00000214193\tSH3D21\tGene Expression\n',
#  'ENSG00000142694\tEVA1B\tGene Expression\n',
#  'ENSG00000286379\tAL591845.1\tGene Expression\n',
#  'ENSG00000196182\tSTK40\tGene Expression\n',
#  'ENSG00000181817\tLSM10\tGene Expression\n',
#  'ENSG00000116885\tOSCP1\tGene Expression\n',
#  'ENSG00000116898\tMRPS15\tGene Expression\n',
#  'ENSG00000119535\tCSF3R\tGene Expression\n',
#  'ENSG00000284705\tAL596257.1\tGene Expression\n',
#  'ENSG00000284720\tAC117945.2\tGene Expression\n',
#  'ENSG00000234481\tAC117945.1\tGene Expression\n',
#  'ENSG00000163873\tGRIK3\tGene Expression\n',
#  'ENSG00000284650\tAL031430.1\tGene Expression\n',
#  'ENSG00000223944\tAL353604.1\tGene Expression\n',
#  'ENSG00000233621\tLINC01137\tGene Expression\n',
#  'ENSG00000163874\tZC3H12A\tGene Expression\n',
#  'ENSG00000163875\tMEAF6\tGene Expression\n',
#  'ENSG00000163877\tSNIP1\tGene Expression\n',
#  'ENSG00000163879\tDNALI1\tGene Expression\n',
#  'ENSG00000134697\tGNL2\tGene Expression\n',
#  'ENSG00000284748\tAL513220.1\tGene Expression\n',
#  'ENSG00000169218\tRSPO1\tGene Expression\n',
#  'ENSG00000116922\tC1orf109\tGene Expression\n',
#  'ENSG00000134690\tCDCA8\tGene Expression\n',
#  'ENSG00000183317\tEPHA10\tGene Expression\n',
#  'ENSG00000185090\tMANEAL\tGene Expression\n',
#  'ENSG00000233728\tAL929472.3\tGene Expression\n',
#  'ENSG00000196449\tYRDC\tGene Expression\n',
#  'ENSG00000197982\tC1orf122\tGene Expression\n',
#  'ENSG00000188786\tMTF1\tGene Expression\n',
#  'ENSG00000230955\tAL929472.2\tGene Expression\n',
#  'ENSG00000204084\tINPP5B\tGene Expression\n',
#  'ENSG00000183431\tSF3A3\tGene Expression\n',
#  'ENSG00000183386\tFHL3\tGene Expression\n',
#  'ENSG00000183520\tUTP11\tGene Expression\n',
#  'ENSG00000185668\tPOU3F1\tGene Expression\n',
#  'ENSG00000224592\tMIR3659HG\tGene Expression\n',
#  'ENSG00000284623\tLINC02786\tGene Expression\n',
#  'ENSG00000286552\tAL390839.1\tGene Expression\n',
#  'ENSG00000287987\tAL390839.2\tGene Expression\n',
#  'ENSG00000237290\tLINC01343\tGene Expression\n',
#  'ENSG00000238063\tLINC01685\tGene Expression\n',
#  'ENSG00000284632\tAL354702.2\tGene Expression\n',
#  'ENSG00000116954\tRRAGC\tGene Expression\n',
#  'ENSG00000228436\tAL139260.1\tGene Expression\n',
#  'ENSG00000214114\tMYCBP\tGene Expression\n',
#  'ENSG00000131233\tGJA9\tGene Expression\n',
#  'ENSG00000158315\tRHBDL2\tGene Expression\n',
#  'ENSG00000174574\tAKIRIN1\tGene Expression\n',
#  'ENSG00000168653\tNDUFS5\tGene Expression\n',
#  'ENSG00000127603\tMACF1\tGene Expression\n',
#  'ENSG00000270040\tAL356055.1\tGene Expression\n',
#  'ENSG00000287422\tAL442071.2\tGene Expression\n',
#  'ENSG00000226438\tAL442071.1\tGene Expression\n',
#  'ENSG00000183682\tBMP8A\tGene Expression\n',
#  'ENSG00000090621\tPABPC4\tGene Expression\n',
#  'ENSG00000228060\tPABPC4-AS1\tGene Expression\n',
#  'ENSG00000163909\tHEYL\tGene Expression\n',
#  'ENSG00000225903\tAL035404.2\tGene Expression\n',
#  'ENSG00000116981\tNT5C1A\tGene Expression\n',
#  'ENSG00000116983\tHPCAL4\tGene Expression\n',
#  'ENSG00000084072\tPPIE\tGene Expression\n',
#  'ENSG00000116985\tBMP8B\tGene Expression\n',
#  'ENSG00000198754\tOXCT2\tGene Expression\n',
#  'ENSG00000285905\tBMP8B-AS1\tGene Expression\n',
#  'ENSG00000261798\tAL033527.3\tGene Expression\n',
#  'ENSG00000284719\tAL033527.4\tGene Expression\n',
#  'ENSG00000284678\tLINC02811\tGene Expression\n',
#  'ENSG00000043514\tTRIT1\tGene Expression\n',
#  'ENSG00000116990\tMYCL\tGene Expression\n',
#  'ENSG00000236546\tAL033527.2\tGene Expression\n',
#  'ENSG00000168389\tMFSD2A\tGene Expression\n',
#  'ENSG00000131236\tCAP1\tGene Expression\n',
#  'ENSG00000131238\tPPT1\tGene Expression\n',
#  'ENSG00000117000\tRLF\tGene Expression\n',
#  'ENSG00000188800\tTMCO2\tGene Expression\n',
#  'ENSG00000259943\tAL050341.2\tGene Expression\n',
#  'ENSG00000084073\tZMPSTE24\tGene Expression\n',
#  'ENSG00000049089\tCOL9A2\tGene Expression\n',
#  'ENSG00000084070\tSMAP2\tGene Expression\n',
#  'ENSG00000284677\tAL031985.4\tGene Expression\n',
#  'ENSG00000187801\tZFP69B\tGene Expression\n',
#  'ENSG00000260920\tAL031985.3\tGene Expression\n',
#  'ENSG00000187815\tZFP69\tGene Expression\n',
#  'ENSG00000238287\tAL603839.3\tGene Expression\n',
#  'ENSG00000164002\tEXO5\tGene Expression\n',
#  'ENSG00000227278\tAL603839.1\tGene Expression\n',
#  'ENSG00000238186\tAL603839.2\tGene Expression\n',
#  'ENSG00000117010\tZNF684\tGene Expression\n',
#  'ENSG00000286838\tAL356379.2\tGene Expression\n',
#  'ENSG00000117016\tRIMS3\tGene Expression\n',
#  'ENSG00000287743\tAL031289.2\tGene Expression\n',
#  'ENSG00000237899\tAL031289.1\tGene Expression\n',
#  'ENSG00000272145\tNFYC-AS1\tGene Expression\n',
#  'ENSG00000066136\tNFYC\tGene Expression\n',
#  'ENSG00000117013\tKCNQ4\tGene Expression\n',
#  'ENSG00000179862\tCITED4\tGene Expression\n',
#  'ENSG00000229528\tAC119677.1\tGene Expression\n',
#  'ENSG00000286668\tAL391730.2\tGene Expression\n',
#  'ENSG00000171793\tCTPS1\tGene Expression\n',
#  'ENSG00000281207\tSLFNL1-AS1\tGene Expression\n',
#  'ENSG00000171790\tSLFNL1\tGene Expression\n',
#  'ENSG00000010803\tSCMH1\tGene Expression\n',
#  'ENSG00000287400\tAC093151.8\tGene Expression\n',
#  'ENSG00000235358\tAC093151.3\tGene Expression\n',
#  'ENSG00000204060\tFOXO6\tGene Expression\n',
#  'ENSG00000229901\tAC093151.2\tGene Expression\n',
#  'ENSG00000127129\tEDN2\tGene Expression\n',
#  'ENSG00000127124\tHIVEP3\tGene Expression\n',
#  'ENSG00000230881\tAL445933.2\tGene Expression\n',
#  'ENSG00000284895\tAC119676.1\tGene Expression\n',
#  'ENSG00000287587\tAL158216.1\tGene Expression\n',
#  'ENSG00000044012\tGUCA2B\tGene Expression\n',
#  'ENSG00000197273\tGUCA2A\tGene Expression\n',
#  'ENSG00000198815\tFOXJ3\tGene Expression\n',
#  'ENSG00000227527\tAC096540.1\tGene Expression\n',
#  'ENSG00000177181\tRIMKLA\tGene Expression\n',
#  'ENSG00000066185\tZMYND12\tGene Expression\n',
#  'ENSG00000127125\tPPCS\tGene Expression\n',
#  'ENSG00000186409\tCCDC30\tGene Expression\n',
#  'ENSG00000171960\tPPIH\tGene Expression\n',
#  'ENSG00000285728\tAC098484.4\tGene Expression\n',
#  'ENSG00000234917\tAC098484.2\tGene Expression\n',
#  'ENSG00000065978\tYBX1\tGene Expression\n',
#  'ENSG00000164007\tCLDN19\tGene Expression\n',
#  'ENSG00000117385\tP3H1\tGene Expression\n',
#  'ENSG00000164008\tC1orf50\tGene Expression\n',
#  'ENSG00000228452\tAC098484.1\tGene Expression\n',
#  'ENSG00000274386\tTMEM269\tGene Expression\n',
#  'ENSG00000177868\tSVBP\tGene Expression\n',
#  'ENSG00000164010\tERMAP\tGene Expression\n',
#  'ENSG00000228192\tAL512353.1\tGene Expression\n',
#  'ENSG00000164011\tZNF691\tGene Expression\n',
#  'ENSG00000117394\tSLC2A1\tGene Expression\n',
#  'ENSG00000227533\tSLC2A1-AS1\tGene Expression\n',
#  'ENSG00000283973\tAC099795.1\tGene Expression\n',
#  'ENSG00000186973\tFAM183A\tGene Expression\n',
#  'ENSG00000117395\tEBNA1BP2\tGene Expression\n',
#  'ENSG00000243710\tCFAP57\tGene Expression\n',
#  'ENSG00000179178\tTMEM125\tGene Expression\n',
#  'ENSG00000253313\tC1orf210\tGene Expression\n',
#  'ENSG00000066056\tTIE1\tGene Expression\n',
#  'ENSG00000117400\tMPL\tGene Expression\n',
#  'ENSG00000287113\tAL139289.3\tGene Expression\n',
#  'ENSG00000234694\tAL139289.2\tGene Expression\n',
#  'ENSG00000117399\tCDC20\tGene Expression\n',
#  'ENSG00000066322\tELOVL1\tGene Expression\n',
#  'ENSG00000159479\tMED8\tGene Expression\n',
#  'ENSG00000229431\tAL139289.1\tGene Expression\n',
#  'ENSG00000198198\tSZT2\tGene Expression\n',
#  'ENSG00000229372\tSZT2-AS1\tGene Expression\n',
#  'ENSG00000178922\tHYI\tGene Expression\n',
#  'ENSG00000229348\tHYI-AS1\tGene Expression\n',
#  'ENSG00000142949\tPTPRF\tGene Expression\n',
#  'ENSG00000066135\tKDM4A\tGene Expression\n',
#  'ENSG00000236200\tKDM4A-AS1\tGene Expression\n',
#  'ENSG00000126091\tST3GAL3\tGene Expression\n',
#  'ENSG00000229444\tAL451062.1\tGene Expression\n',
#  'ENSG00000117407\tARTN\tGene Expression\n',
#  'ENSG00000237950\tAL357079.1\tGene Expression\n',
#  'ENSG00000117408\tIPO13\tGene Expression\n',
#  'ENSG00000285649\tAL357079.2\tGene Expression\n',
#  'ENSG00000132768\tDPH2\tGene Expression\n',
#  'ENSG00000117410\tATP6V0B\tGene Expression\n',
#  'ENSG00000117411\tB4GALT2\tGene Expression\n',
#  'ENSG00000159214\tCCDC24\tGene Expression\n',
#  'ENSG00000196517\tSLC6A9\tGene Expression\n',
#  'ENSG00000230615\tAL139220.2\tGene Expression\n',
#  'ENSG00000171872\tKLF17\tGene Expression\n',
#  'ENSG00000283039\tKLF18\tGene Expression\n',
#  'ENSG00000178028\tDMAP1\tGene Expression\n',
#  'ENSG00000117419\tERI3\tGene Expression\n',
#  'ENSG00000233602\tERI3-IT1\tGene Expression\n',
#  'ENSG00000187147\tRNF220\tGene Expression\n',
#  'ENSG00000126106\tTMEM53\tGene Expression\n',
#  'ENSG00000198520\tARMH1\tGene Expression\n',
#  'ENSG00000142945\tKIF2C\tGene Expression\n',
#  'ENSG00000225721\tAL592166.1\tGene Expression\n',
#  'ENSG00000142937\tRPS8\tGene Expression\n',
#  'ENSG00000142959\tBEST4\tGene Expression\n',
#  'ENSG00000173846\tPLK3\tGene Expression\n',
#  'ENSG00000188396\tTCTEX1D4\tGene Expression\n',
#  'ENSG00000222009\tBTBD19\tGene Expression\n',
#  'ENSG00000117425\tPTCH2\tGene Expression\n',
#  'ENSG00000070785\tEIF2B3\tGene Expression\n',
#  'ENSG00000126107\tHECTD3\tGene Expression\n',
#  'ENSG00000126088\tUROD\tGene Expression\n',
#  'ENSG00000162415\tZSWIM5\tGene Expression\n',
#  'ENSG00000281912\tLINC01144\tGene Expression\n',
#  'ENSG00000186603\tHPDL\tGene Expression\n',
#  'ENSG00000132781\tMUTYH\tGene Expression\n',
#  'ENSG00000132773\tTOE1\tGene Expression\n',
#  'ENSG00000070759\tTESK2\tGene Expression\n',
#  'ENSG00000280670\tCCDC163\tGene Expression\n',
#  'ENSG00000132763\tMMACHC\tGene Expression\n',
#  'ENSG00000117450\tPRDX1\tGene Expression\n',
#  'ENSG00000117448\tAKR1A1\tGene Expression\n',
#  'ENSG00000132780\tNASP\tGene Expression\n',
#  'ENSG00000159588\tCCDC17\tGene Expression\n',
#  'ENSG00000159592\tGPBP1L1\tGene Expression\n',
#  'ENSG00000159596\tTMEM69\tGene Expression\n',
#  'ENSG00000197429\tIPP\tGene Expression\n',
#  'ENSG00000230896\tAL604028.1\tGene Expression\n',
#  ...]

# %% [markdown]
# ## Q3 (1 pt). How many nonzero entries are there in the counts matrix, which stores all the observed features (mRNA transcripts or surface proteins) for all the cells? In other words, how many cell-feature combinations were observed in the experiment?
# Figure this out by reading the lines from `matrix_file` into a list, and printing the length of that list *MINUS 3* because the matrix file starts with three header lines (two comments and a line showing the overall size of the matrix).

# %%
# your code here

# %% [markdown]
# ## Q4 (1 pt). Print the third line in the matrix file (counting lines as we normally do 1,2,3,...).
# This line should relate to your previous answers.

# %%
# your code here

# %% [markdown]
# ## Q5 (2 pts). Write a function that reads the features file and returns a list of the gene/protein names, as a list of strings. Use this function to get a list of the features and print the name of the 100th feature (here counting 1,2,3...).
# The features file has three, tab-separated columns and no header line. The names that we are looking for are in the second (ie, middle) column. These are the usual human-readable gene names like 'CD4' and 'CCL5'.

# %%
## you can fill out this function

def read_feature_names(filename):
    ''' Return a list of the feature names
    '''
    lines = read_lines_from_file(filename)
    # etc, etc
    
    
features = read_feature_names(features_file)
print(features[YOU_PUT_THE_RIGHT_NUMBER_IN_HERE])

# %% [markdown]
# ## Q6 (2 pts). Write a function that takes as input a cell number and a matrix filename and returns the total transcript count for all the features mapped to that cell number. In other words, the sum of all the transcript counts for all the features that were mapped to that cell. So, a single number.
# Start from the template below. The matrix file starts with three header lines. Every other line in the file consists of three integers: the feature number, the cell number, and the count for that feature (the number of unique transcripts mapping to that feature).

# %%
def get_total_count_for_cell(cell_number, matrix_filename):
    ''' Read through the matrix file and sum up all the counts for features 
    that mapped to the given cell_number. cell_number is a 1-indexed integer,
    just like the feature and cell indexes in the matrix file. I.e., it starts at 1.
    '''
    assert cell_number>0 # cell_number should be 1-indexed. 0 is not a valid cell nunber.
    
    # here we read the lines from the file, and use slicing to remove the first three header lines:
    lines = read_lines_from_file(matrix_filename)[3:]
    total_count = 0
        
    # etc etc

# %% [markdown]
# ## Q7 (2 pts). Use the function you created above to print out the total feature count for each cell in the dataset. Which cell number (1-10) has the highest total number of transcripts? Which has the lowest?
# Use a `for` loop over a `range` expression to loop over the cell numbers when printing out the total feature counts. You can just eyeball the numbers to identify the cells with the largest and smallest counts. Or you could append them to a list and use the `max()` `min()` and `list.index()` functions.

# %%
# your code here

# %% [markdown]
# ## Q8 (2 pts extra credit). Write a function that takes as input a cell number, a list of all the features, and a matrix filename and returns a tuple (name, count) consisting of the name of the feature with the highest transcript count in that cell and the count for that feature. Use this to figure out the highest count feature for each of the 10 cells.
# One tricky thing is the disconnect between how the features are numbered in the matrix file and how they are numbered in python lists.

# %%
def get_highest_feature(cell_number, features, matrix_filename):
    ''' Read through the matrix file and find the feature with the highest count
    for the given cell. Return the feature name and the count for that feature
    '''
    # fill this in

# %% [markdown]
# # Potentially useful code snippets

# %%
# parsing a single line...

line = '4 6 20\n'
line_split = line.split()
print(line_split) #strings

#this is something called a list comprehension: it's a nice, short-hand way of creating a list in python
# the general syntax is:
#  [ expression_involving_variable for variable in list ]
# or you can add an if-statement to filter out some elements:
#  [ expression_involving_variable for variable in list if boolean_involving_variable ]

counts = [int(x) for x in line_split] 
 
print(counts) # now integers

a, b, c = counts # in python we can assign to multiple names using a list (or other "iterable" like a tuple) 
print('a=', a)
print('b=', b)
print('c=', c)

# %%
# max and min and index

l = [3, 7, 4, -1, 10, 6]

# max and min are built-in python functions that can operate on integers, floats, lists, and many other objects  
print('max(3,4)=', max(3,4))
print('min(2,10,-1,59)=', min(2,10,-1,59))

print('max(l)=', max(l))
print('min(l)=', min(l))

# l.index is a function that returns the index where a given element occurs in a list

print('index for max(l) in l:', l.index(max(l)))
